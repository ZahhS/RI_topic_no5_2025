# %%
pip install trec-car-tools
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting trec-car-tools
#   Downloading trec_car_tools-2.6-py3-none-any.whl (8.4 kB)
# Collecting cbor>=1.0.0
#   Downloading cbor-1.0.0.tar.gz (20 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: numpy>=1.11.2 in /users/Etu0/21410720/.local/lib/python3.11/site-packages (from trec-car-tools) (1.26.4)
# Building wheels for collected packages: cbor
#   Building wheel for cbor (setup.py) ... done
#   Created wheel for cbor: filename=cbor-1.0.0-cp311-cp311-linux_x86_64.whl size=53539 sha256=876a2f440ad51c69b23f76f782b6b7b55bee8dbf968f568193cc0916fef84321
#   Stored in directory: /users/nfs/Etu0/21410720/.cache/pip/wheels/21/6b/45/0c34253b1af07d1d9dc524f6d44d74a6b191c43152e6aaf641
# Successfully built cbor
# Installing collected packages: cbor, trec-car-tools
# Successfully installed cbor-1.0.0 trec-car-tools-2.6
# Note: you may need to restart the kernel to use updated packages.

# %%
import trec_car.read_data as trec_car

file_path = "benchmarkY2.cbor-outlines.cbor"

with open(file_path, 'rb') as f:
    for page in trec_car.iter_outlines(f):
        print("Page:", page.page_name)
        for section_path in page.flat_headings_list():
            # Chaque section_path est déjà une liste de SectionHeading
            heading_text = " / ".join([h.heading for h in section_path])
            print("   ↳ Subtopic:", heading_text)
# Out:
# Page: relative ages of rocks
#    ↳ Subtopic: Matching Rock Layers
#    ↳ Subtopic: Putting Events in Order
#    ↳ Subtopic: Law of Superposition
#    ↳ Subtopic: Widespread Rock Layers
#    ↳ Subtopic: Law of Lateral Continuity
#    ↳ Subtopic: Dividing Geologic Time
#    ↳ Subtopic: The Geologic Time Scale
#    ↳ Subtopic: Law of Original Horizontality
#    ↳ Subtopic: Your Place in Geologic Time
#    ↳ Subtopic: Law of CrossCutting Relationships
#    ↳ Subtopic: Using Index Fossils
#    ↳ Subtopic: Life and the Geologic Time Scale
#    ↳ Subtopic: Key Beds
#    ↳ Subtopic: Unconformities
#    ↳ Subtopic: Laws of Stratigraphy
#    ↳ Subtopic: Divisions of the Geologic Time Scale
# Page: absolute ages of rocks
#    ↳ Subtopic: Isotopes
#    ↳ Subtopic: Decay of Unstable Isotopes
#    ↳ Subtopic: Radiometric Dating
#    ↳ Subtopic: Radioactive Decay
#    ↳ Subtopic: Carbon14 Dating
#    ↳ Subtopic: Other Radioactive Isotopes
# Page: energy in the atmosphere
#    ↳ Subtopic: Radiation
#    ↳ Subtopic: The Greenhouse Effect
#    ↳ Subtopic: What Is Energy
#    ↳ Subtopic: Energy and Latitude
#    ↳ Subtopic: Forms of Energy
#    ↳ Subtopic: Photons of Energy
#    ↳ Subtopic: Movement of Energy
#    ↳ Subtopic: Electromagnetic Spectrum
#    ↳ Subtopic: Conduction
#    ↳ Subtopic: Energy from the Sun
#    ↳ Subtopic: How Energy Moves Through the Atmosphere
#    ↳ Subtopic: Convection
# Page: world climates
#    ↳ Subtopic: Major Climate Types
#    ↳ Subtopic: Tropical Climates
#    ↳ Subtopic: Continental Climates
#    ↳ Subtopic: Dry Climates
#    ↳ Subtopic: Microclimates
#    ↳ Subtopic: Polar Climates
#    ↳ Subtopic: Temperate Climates
# Page: climate change
#    ↳ Subtopic: Causes of Climate Change in Earth History
#    ↳ Subtopic: ShortTerm Climate Change
#    ↳ Subtopic: How Earths Climate Has Changed
#    ↳ Subtopic: El Nio
#    ↳ Subtopic: Explaining LongTerm Climate Change
#    ↳ Subtopic: Pleistocene Ice Age
#    ↳ Subtopic: Earths Recent Temperature
#    ↳ Subtopic: La Nia
#    ↳ Subtopic: How Will Climate Change in the Future
#    ↳ Subtopic: The Big Picture
#    ↳ Subtopic: Causes of Global Warming
#    ↳ Subtopic: Effects of Global Warming
#    ↳ Subtopic: Global Warming and ShortTerm Climate Change
# Page: humans and the water supply
#    ↳ Subtopic: How We Use Water
#    ↳ Subtopic: Where Is All the Water
#    ↳ Subtopic: Water Problems Not Enough Water
#    ↳ Subtopic: Water in Industry
#    ↳ Subtopic: Water Shortages
#    ↳ Subtopic: Wealth and the Water Supply
#    ↳ Subtopic: Water in Agriculture
#    ↳ Subtopic: Rainfall and the Water Supply
#    ↳ Subtopic: Water Problems Poor Quality Water
#    ↳ Subtopic: Water for Fun
#    ↳ Subtopic: Household Uses of Water
# Page: protecting the water supply
#    ↳ Subtopic: Rationing Water
#    ↳ Subtopic: Reducing Water Pollution
#    ↳ Subtopic: Saving Water in Irrigation
#    ↳ Subtopic: Conserving Water
#    ↳ Subtopic: Water Treatment
#    ↳ Subtopic: What You Can Do
#    ↳ Subtopic: Saving Water at Home
#    ↳ Subtopic: Controlling Water Pollution
# Page: air pollution
#    ↳ Subtopic: Air Pollution in the U.S.
#    ↳ Subtopic: Evaporation of VOCs
#    ↳ Subtopic: Primary Pollutants
#    ↳ Subtopic: Air Quality
#    ↳ Subtopic: Secondary Pollutants
#    ↳ Subtopic: Burning Forests
#    ↳ Subtopic: The Industrial Revolution
#    ↳ Subtopic: The Clean Air Act
#    ↳ Subtopic: Types of Air Pollutants
#    ↳ Subtopic: Burning Fossil Fuels
#    ↳ Subtopic: The Big Smoke
#    ↳ Subtopic: Sources of Air Pollution
# Page: reducing air pollution
#    ↳ Subtopic: Keeping Pollutants out of the Air
#    ↳ Subtopic: Controlling Global Warming
#    ↳ Subtopic: Protecting the Ozone Layer
#    ↳ Subtopic: Reducing Air Pollution from Fossil Fuels
#    ↳ Subtopic: Preventing Ozone Loss and Global Warming
#    ↳ Subtopic: Using Less Fossil Fuel
# Page: earths energy
#    ↳ Subtopic: Energy Fuel and Heat
#    ↳ Subtopic: Types of Renewable Resources
#    ↳ Subtopic: The Sources of Earths Energy
#    ↳ Subtopic: Energy
#    ↳ Subtopic: Important Things to Consider About Energy Resources
#    ↳ Subtopic: The Need for Energy
#    ↳ Subtopic: Fuel
#    ↳ Subtopic: KQED Climate Watch Unlocking the Grid
#    ↳ Subtopic: Conservation of Energy
#    ↳ Subtopic: Heat
#    ↳ Subtopic: Energy Changes
#    ↳ Subtopic: Types of Energy Resources
#    ↳ Subtopic: Types of Nonrenewable Resources
# Page: renewable energy resources
#    ↳ Subtopic: Biomass
#    ↳ Subtopic: Solar Energy
#    ↳ Subtopic: Wind as a Resource
#    ↳ Subtopic: Geothermal Energy
#    ↳ Subtopic: Hydropower Plants
#    ↳ Subtopic: Wind Power Advantages and Disadvantages
#    ↳ Subtopic: Geothermal Energy as a Resource
#    ↳ Subtopic: Benefits and Problems of Hydropower
#    ↳ Subtopic: Water Power
#    ↳ Subtopic: Solar Power Plants
#    ↳ Subtopic: KQED Geothermal Heats Up
#    ↳ Subtopic: Hydropower as a Resource
#    ↳ Subtopic: Consequences of Solar Energy Use
#    ↳ Subtopic: Solar Energy as a Resource
#    ↳ Subtopic: KQED Harnessing Power from the Sea
#    ↳ Subtopic: Solar Energy Use
#    ↳ Subtopic: Energy from the Sun
#    ↳ Subtopic: Wind Power
# Page: stress in earths crust
#    ↳ Subtopic: StrikeSlip
#    ↳ Subtopic: Faults
#    ↳ Subtopic: Causes and Types of Stress
#    ↳ Subtopic: Rifting
#    ↳ Subtopic: Stress and Mountain Building
#    ↳ Subtopic: Oceanic Plate Subduction
#    ↳ Subtopic: San Andreas Fault
#    ↳ Subtopic: Folds
#    ↳ Subtopic: ContinentContinent Convergence
#    ↳ Subtopic: Geologic Structures
# Page: igneous landforms and geothermal activ
#    ↳ Subtopic: Geysers
#    ↳ Subtopic: Hot Springs
#    ↳ Subtopic: Hot Springs and Geysers
#    ↳ Subtopic: Lava Plateaus
#    ↳ Subtopic: Lava Domes
#    ↳ Subtopic: Landforms from Magma
#    ↳ Subtopic: New Land
#    ↳ Subtopic: Landforms from Lava
# Page: agriculture and human population growth
#    ↳ Subtopic: Advances in Agriculture and Population
#    ↳ Subtopic: The Industrial Revolution
#    ↳ Subtopic: Farming
#    ↳ Subtopic: Hunters and Gatherers
#    ↳ Subtopic: The Future
#    ↳ Subtopic: The Green Revolution
# Page: availability of natural resources
#    ↳ Subtopic: Politics
#    ↳ Subtopic: Waste
#    ↳ Subtopic: Price
#    ↳ Subtopic: Supply
#    ↳ Subtopic: Resource Availability
# Page: glaciers
#    ↳ Subtopic: Movement
#    ↳ Subtopic: Glaciers as a Resource
#    ↳ Subtopic: Types of Glaciers
#    ↳ Subtopic: Glacial Growth
#    ↳ Subtopic: Shrinking
#    ↳ Subtopic: Glacier National Park
#    ↳ Subtopic: Where are the Glaciers
#    ↳ Subtopic: Formation
# Page: uses of water
#    ↳ Subtopic: Environmental Use
#    ↳ Subtopic: Why Not Change
#    ↳ Subtopic: Water Consumption
#    ↳ Subtopic: Household Use
#    ↳ Subtopic: Nonwasteful Methods
#    ↳ Subtopic: Recreational Use
#    ↳ Subtopic: Agriculture
#    ↳ Subtopic: Wasteful Methods
#    ↳ Subtopic: Industrial Water Use
#    ↳ Subtopic: Human Uses of Water
#    ↳ Subtopic: Aquaculture
#    ↳ Subtopic: Aquaculture Problems
# Page: water distribution
#    ↳ Subtopic: Conflicts Over Water
#    ↳ Subtopic: Water Distribution
#    ↳ Subtopic: Water Shortages
#    ↳ Subtopic: Water Scarcity
#    ↳ Subtopic: Effect of Changing Climate
#    ↳ Subtopic: Droughts
# Page: blood
#    ↳ Subtopic: ABO Blood Type
#    ↳ Subtopic: Blood Type
#    ↳ Subtopic: Hemophilia
#    ↳ Subtopic: Functions of Blood
#    ↳ Subtopic: SickleCell Disease
#    ↳ Subtopic: Blood Components
#    ↳ Subtopic: Diseases of the Blood
#    ↳ Subtopic: Anemia
#    ↳ Subtopic: Structure and Functions of Blood
#    ↳ Subtopic: Leukemia
#    ↳ Subtopic: Rhesus Blood Type
# Page: darwins theory of evolution
#    ↳ Subtopic: Evolution of Darwins Theory
#    ↳ Subtopic: Plant and Animal Breeding
#    ↳ Subtopic: Darwins Theory in a Nutshell
#    ↳ Subtopic: Putting It All Together
#    ↳ Subtopic: Other Scientists
#    ↳ Subtopic: Voyage of the
#    ↳ Subtopic: Giant Tortoises
#    ↳ Subtopic: Darwins Book
#    ↳ Subtopic: Darwins Finches
#    ↳ Subtopic: More Influences on Darwin
# Page: evidence for evolution
#    ↳ Subtopic: Evidence from Living Organisms
#    ↳ Subtopic: Observing Evolution in Action
#    ↳ Subtopic: Using Fossils to Understand Evolution
#    ↳ Subtopic: What Are Fossils
#    ↳ Subtopic: Comparing Molecules
#    ↳ Subtopic: Vestigial Structures
#    ↳ Subtopic: Comparing Embryos
#    ↳ Subtopic: Comparing Body Parts
#    ↳ Subtopic: How Fossils Are Dated
#    ↳ Subtopic: How Fossils Form
# Page: the scale of evolution
#    ↳ Subtopic: Two Scales of Evolution
#    ↳ Subtopic: Speciation
#    ↳ Subtopic: Rate of Evolution
#    ↳ Subtopic: Genes in Populations
#    ↳ Subtopic: Microevolution
#    ↳ Subtopic: Macroevolution
#    ↳ Subtopic: Coevolution
#    ↳ Subtopic: Convergent Evolution
#    ↳ Subtopic: Forces of Evolution
# Page: effects of water pollution
#    ↳ Subtopic: Ocean Acidification
#    ↳ Subtopic: Effects of Water Pollution
#    ↳ Subtopic: Eutrophication
#    ↳ Subtopic: Waterborne Diseases
#    ↳ Subtopic: Aquatic Debris
# Page: population growth patterns
#    ↳ Subtopic: Migration
#    ↳ Subtopic: Exponential Growth
#    ↳ Subtopic: Births Deaths and Migration
#    ↳ Subtopic: Population Growth
# Page: pregnancy and childbirth
#    ↳ Subtopic: The Amniotic Sac and Placenta
#    ↳ Subtopic: Childbirth
#    ↳ Subtopic: Growth and Development of the Embryo
#    ↳ Subtopic: Growth and Development of the Fetus
#    ↳ Subtopic: Pregnancy and Childbirth
# Page: skin
#    ↳ Subtopic: Functions of Skin
#    ↳ Subtopic: Structure of Skin
#    ↳ Subtopic: The Epidermis
#    ↳ Subtopic: Your Skin
#    ↳ Subtopic: The Dermis
#    ↳ Subtopic: Oil Glands and Sweat Glands
# Page: acids and bases
#    ↳ Subtopic: Uses of Acids
#    ↳ Subtopic: The pH Scale
#    ↳ Subtopic: Acids
#    ↳ Subtopic: Reactions of Acids and Bases
#    ↳ Subtopic: Concentration of Ions
#    ↳ Subtopic: Detecting Bases
#    ↳ Subtopic: Properties of Acids
#    ↳ Subtopic: Why pH Matters
#    ↳ Subtopic: Strength of Acids and Bases
#    ↳ Subtopic: Properties of Bases
#    ↳ Subtopic: Detecting Acids
#    ↳ Subtopic: Uses of Bases
#    ↳ Subtopic: Bases
# Page: machines
#    ↳ Subtopic: Mechanical Advantage and Type of Machine
#    ↳ Subtopic: Increasing Distance
#    ↳ Subtopic: Calculating Efficiency
#    ↳ Subtopic: Increasing Force
#    ↳ Subtopic: Mechanical Advantage of Machines
#    ↳ Subtopic: KQED Exoskeletons Walk Forward
#    ↳ Subtopic: Efficiency of Machines
#    ↳ Subtopic: Changing the Direction of Force
#    ↳ Subtopic: How Machines Help Us Do Work
#    ↳ Subtopic: An Example Efficiency of a Ramp
#    ↳ Subtopic: Ideal Mechanical Advantage
# Page: history of the atom
#    ↳ Subtopic: Thomsons Plum Pudding Model
#    ↳ Subtopic: Daltons Research
#    ↳ Subtopic: Dalton Brings Back the Atom
#    ↳ Subtopic: Thomsons Vacuum Tube Experiments
#    ↳ Subtopic: Democritus Introduces the Atom
#    ↳ Subtopic: Daltons Atomic Models
#    ↳ Subtopic: Thomson Adds Electrons
#    ↳ Subtopic: The Nucleus and Its Particles
#    ↳ Subtopic: Rutherfords Atomic Model
#    ↳ Subtopic: Daltons Atomic Theory
#    ↳ Subtopic: Rutherford Finds the Nucleus
#    ↳ Subtopic: Rutherfords Gold Foil Experiments
# Page: carbon and living things
#    ↳ Subtopic: Lipids
#    ↳ Subtopic: Phospholipids
#    ↳ Subtopic: Fatty Acids
#    ↳ Subtopic: Starches
#    ↳ Subtopic: Nucleic Acids
#    ↳ Subtopic: Proteins
#    ↳ Subtopic: Protein Structure
#    ↳ Subtopic: Sugars
#    ↳ Subtopic: Cellulose
#    ↳ Subtopic: Protein Functions
#    ↳ Subtopic: Carbohydrates
#    ↳ Subtopic: Structure of Nucleic Acids
#    ↳ Subtopic: Biochemical Compounds
#    ↳ Subtopic: Functions of Nucleic Acids
# Page: artificial light
#    ↳ Subtopic: Incandescent Light
#    ↳ Subtopic: Vapor Light
#    ↳ Subtopic: Neon Light
#    ↳ Subtopic: Turn on the Lights
#    ↳ Subtopic: LED Light
#    ↳ Subtopic: Fluorescent Light
# Page: Alternative medicine
#    ↳ Subtopic: Appeal
#    ↳ Subtopic: Appeal / Marketing
#    ↳ Subtopic: Appeal / A failure of mainstream medicine
#    ↳ Subtopic: Appeal / Social factors
#    ↳ Subtopic: Definitions and terminology
#    ↳ Subtopic: Definitions and terminology / Alternative medicine
#    ↳ Subtopic: Definitions and terminology / Complementary or integrative medicine
#    ↳ Subtopic: Definitions and terminology / Allopathic medicine
#    ↳ Subtopic: Definitions and terminology / CAM
#    ↳ Subtopic: Definitions and terminology / Traditional medicine
#    ↳ Subtopic: Definitions and terminology / Problems with definition
#    ↳ Subtopic: Definitions and terminology / Different types of definitions
#    ↳ Subtopic: Definitions and terminology / NCCIH classification
#    ↳ Subtopic: Types
#    ↳ Subtopic: Types / Unscientific belief systems
#    ↳ Subtopic: Types / Traditional ethnic systems
#    ↳ Subtopic: Types / Supernatural energies
#    ↳ Subtopic: Types / Herbal remedies and other substances used
#    ↳ Subtopic: History
#    ↳ Subtopic: History / Individual systems and practices
#    ↳ Subtopic: History / "Irregular practitioners"
#    ↳ Subtopic: History / Medical education
#    ↳ Subtopic: History / United States government
#    ↳ Subtopic: Efficacy
#    ↳ Subtopic: Criticism, legitimacy and effects
#    ↳ Subtopic: Placebo effect
#    ↳ Subtopic: Use and regulation
#    ↳ Subtopic: Use and regulation / Prevalence of use
#    ↳ Subtopic: Use and regulation / Prevalence of use / In the US
#    ↳ Subtopic: Use and regulation / Prevalence of use / Prevalence of use of specific therapies
#    ↳ Subtopic: Use and regulation / Prevalence of use / In palliative care
#    ↳ Subtopic: Use and regulation / Regulation
#    ↳ Subtopic: Conflicts of interest
#    ↳ Subtopic: Risks
#    ↳ Subtopic: Risks / Adequacy of regulation and CAM safety
#    ↳ Subtopic: Risks / Interactions with conventional pharmaceuticals
#    ↳ Subtopic: Risks / Potential side-effects
#    ↳ Subtopic: Risks / Treatment delay
#    ↳ Subtopic: Risks / Unconventional cancer "cures"
# Page: Chiropractic
#    ↳ Subtopic: Conceptual basis
#    ↳ Subtopic: Conceptual basis / Philosophy
#    ↳ Subtopic: Conceptual basis / Straights and mixers
#    ↳ Subtopic: Conceptual basis / Vertebral subluxation
#    ↳ Subtopic: Scope of practice
#    ↳ Subtopic: Treatments
#    ↳ Subtopic: Treatments / Practice guidelines
#    ↳ Subtopic: Treatments / Effectiveness
#    ↳ Subtopic: Treatments / Safety
#    ↳ Subtopic: Treatments / Risk-benefit
#    ↳ Subtopic: Treatments / Cost-effectiveness
#    ↳ Subtopic: Education, licensing, and regulation
#    ↳ Subtopic: Education, licensing, and regulation / Ethics
#    ↳ Subtopic: Reception
#    ↳ Subtopic: Reception / Australia
#    ↳ Subtopic: Reception / United Kingdom
#    ↳ Subtopic: Reception / United States and Canada
#    ↳ Subtopic: History
#    ↳ Subtopic: Public health
#    ↳ Subtopic: Controversy
# Page: Radiocarbon dating
#    ↳ Subtopic: Background
#    ↳ Subtopic: Background / History
#    ↳ Subtopic: Background / Physical and chemical details
#    ↳ Subtopic: Background / Principles
#    ↳ Subtopic: Background / Carbon exchange reservoir
#    ↳ Subtopic: Dating considerations
#    ↳ Subtopic: Dating considerations / Atmospheric variation
#    ↳ Subtopic: Dating considerations / Isotopic fractionation
#    ↳ Subtopic: Dating considerations / Reservoir effects
#    ↳ Subtopic: Dating considerations / Contamination
#    ↳ Subtopic: Samples
#    ↳ Subtopic: Samples / Material considerations
#    ↳ Subtopic: Samples / Preparation and size
#    ↳ Subtopic: Measurement and results
#    ↳ Subtopic: Measurement and results / Beta counting
#    ↳ Subtopic: Measurement and results / Accelerator mass spectrometry
#    ↳ Subtopic: Measurement and results / Calculations
#    ↳ Subtopic: Measurement and results / Errors and reliability
#    ↳ Subtopic: Measurement and results / Calibration
#    ↳ Subtopic: Measurement and results / Reporting dates
#    ↳ Subtopic: Use in archaeology
#    ↳ Subtopic: Use in archaeology / Interpretation
#    ↳ Subtopic: Use in archaeology / Notable applications
#    ↳ Subtopic: Use in archaeology / Notable applications / Pleistocene/Holocene boundary in Two Creeks Fossil Forest
#    ↳ Subtopic: Use in archaeology / Notable applications / Dead Sea Scrolls
#    ↳ Subtopic: Use in archaeology / Impact
# Page: Breakdancing
#    ↳ Subtopic: Terminology
#    ↳ Subtopic: History
#    ↳ Subtopic: History / Uprock
#    ↳ Subtopic: Worldwide expansion
#    ↳ Subtopic: Worldwide expansion / Brazil
#    ↳ Subtopic: Worldwide expansion / Cambodia
#    ↳ Subtopic: Worldwide expansion / Canada
#    ↳ Subtopic: Worldwide expansion / France
#    ↳ Subtopic: Worldwide expansion / Japan
#    ↳ Subtopic: Worldwide expansion / South Korea
#    ↳ Subtopic: Dance elements
#    ↳ Subtopic: Styles
#    ↳ Subtopic: Styles / Downrock styles
#    ↳ Subtopic: Styles / Power versus style
#    ↳ Subtopic: Music
#    ↳ Subtopic: World championships
#    ↳ Subtopic: Female presence
#    ↳ Subtopic: Media exposure
#    ↳ Subtopic: Media exposure / Film
#    ↳ Subtopic: Media exposure / Television
#    ↳ Subtopic: Media exposure / Literature
#    ↳ Subtopic: Media exposure / Video gaming
# Page: Arab slave trade
#    ↳ Subtopic: Scope of the trade
#    ↳ Subtopic: History of the Arab slave trade
#    ↳ Subtopic: History of the Arab slave trade / Arab slaves
#    ↳ Subtopic: Historical and geographical context
#    ↳ Subtopic: Historical and geographical context / Islamic world
#    ↳ Subtopic: Historical and geographical context / Arab views on African peoples
#    ↳ Subtopic: Historical and geographical context / Africa: 8th through 19th centuries
#    ↳ Subtopic: Geography of the slave trade
#    ↳ Subtopic: Geography of the slave trade / "Supply" zones
#    ↳ Subtopic: Geography of the slave trade / Routes
#    ↳ Subtopic: Geography of the slave trade / Barter
#    ↳ Subtopic: Geography of the slave trade / Slave markets and fairs
#    ↳ Subtopic: Legacy
#    ↳ Subtopic: Primary sources
#    ↳ Subtopic: Primary sources / Medieval Arabic sources
#    ↳ Subtopic: Primary sources / European texts (16th–19th centuries)
#    ↳ Subtopic: Primary sources / Other sources
# Page: Mate (drink)
#    ↳ Subtopic: Name
#    ↳ Subtopic: Preparation
#    ↳ Subtopic: Preparation / Brewing
#    ↳ Subtopic: Etiquette
#    ↳ Subtopic: History
#    ↳ Subtopic: Culture
#    ↳ Subtopic: Health effects
#    ↳ Subtopic: Other properties
#    ↳ Subtopic: Legendary origins
#    ↳ Subtopic: Variants
# Page: Hybrid electric vehicle
#    ↳ Subtopic: Classification
#    ↳ Subtopic: Classification / Types of powertrain
#    ↳ Subtopic: Classification / Types by degree of hybridization
#    ↳ Subtopic: Classification / Plug-in hybrids (PHEVs)
#    ↳ Subtopic: History
#    ↳ Subtopic: History / Early days
#    ↳ Subtopic: History / Predecessors of present technology
#    ↳ Subtopic: History / Modern hybrids
#    ↳ Subtopic: History / Latest developments
#    ↳ Subtopic: Sales and rankings
#    ↳ Subtopic: Sales and rankings / Japanese market
#    ↳ Subtopic: Sales and rankings / American market
#    ↳ Subtopic: Sales and rankings / European market
#    ↳ Subtopic: Technology
#    ↳ Subtopic: Technology / Engines and fuel sources
#    ↳ Subtopic: Technology / Engines and fuel sources / Fossil fuels
#    ↳ Subtopic: Technology / Engines and fuel sources / Biofuels
#    ↳ Subtopic: Technology / Electric machines
#    ↳ Subtopic: Technology / Design considerations
#    ↳ Subtopic: Technology / Conversion kits
#    ↳ Subtopic: Environmental impact
#    ↳ Subtopic: Environmental impact / Fuel consumption
#    ↳ Subtopic: Environmental impact / Noise
#    ↳ Subtopic: Environmental impact / Pollution
#    ↳ Subtopic: Environmental impact / Top ten EPA-rated hybrids
#    ↳ Subtopic: Vehicle types
#    ↳ Subtopic: Vehicle types / Motorcycles
#    ↳ Subtopic: Vehicle types / High-performance cars
#    ↳ Subtopic: Vehicle types / Formula 1
#    ↳ Subtopic: Vehicle types / Taxis
#    ↳ Subtopic: Vehicle types / Buses
#    ↳ Subtopic: Vehicle types / Trucks
#    ↳ Subtopic: Vehicle types / Military vehicles
#    ↳ Subtopic: Vehicle types / Locomotives
#    ↳ Subtopic: Vehicle types / Marine and other aquatic
#    ↳ Subtopic: Vehicle types / Aircraft
#    ↳ Subtopic: Hybrid premium and showroom cost parity
#    ↳ Subtopic: Raw materials shortage
#    ↳ Subtopic: Legislation and incentives
#    ↳ Subtopic: Legislation and incentives / Canada
#    ↳ Subtopic: Legislation and incentives / Israel
#    ↳ Subtopic: Legislation and incentives / Japan
#    ↳ Subtopic: Legislation and incentives / Jordan
#    ↳ Subtopic: Legislation and incentives / Malaysia
#    ↳ Subtopic: Legislation and incentives / Netherlands
#    ↳ Subtopic: Legislation and incentives / New Zealand
#    ↳ Subtopic: Legislation and incentives / Republic of Ireland
#    ↳ Subtopic: Legislation and incentives / Sweden
#    ↳ Subtopic: Legislation and incentives / United Kingdom
#    ↳ Subtopic: Legislation and incentives / United States
#    ↳ Subtopic: Legislation and incentives / United States / Federal
#    ↳ Subtopic: Legislation and incentives / United States / States and local
# Page: Gunshot wound
#    ↳ Subtopic: Signs and symptoms
#    ↳ Subtopic: Classification
#    ↳ Subtopic: Physics
#    ↳ Subtopic: Firearm
#    ↳ Subtopic: Management
#    ↳ Subtopic: Management / Workup
#    ↳ Subtopic: Management / Neck
#    ↳ Subtopic: Management / Chest
#    ↳ Subtopic: Management / Abdomen
#    ↳ Subtopic: Management / Extremities
#    ↳ Subtopic: Epidemiology
#    ↳ Subtopic: Epidemiology / United States
#    ↳ Subtopic: History
#    ↳ Subtopic: Research
# Page: Zika fever
#    ↳ Subtopic: Signs and symptoms
#    ↳ Subtopic: Signs and symptoms / Guillain–Barré syndrome
#    ↳ Subtopic: Signs and symptoms / Pregnancy
#    ↳ Subtopic: Cause
#    ↳ Subtopic: Cause / Reservoir
#    ↳ Subtopic: Cause / Transmission
#    ↳ Subtopic: Pathophysiology
#    ↳ Subtopic: Diagnosis
#    ↳ Subtopic: Diagnosis / Screening in pregnancy
#    ↳ Subtopic: Diagnosis / Infant testing
#    ↳ Subtopic: Prevention
#    ↳ Subtopic: Prevention / CDC travel alert
#    ↳ Subtopic: Prevention / WHO response
#    ↳ Subtopic: Prevention / Vaccine
#    ↳ Subtopic: Prevention / Mosquito control
#    ↳ Subtopic: Treatment
#    ↳ Subtopic: Outcomes
#    ↳ Subtopic: Epidemiology
#    ↳ Subtopic: Epidemiology / Yap Islands
#    ↳ Subtopic: Epidemiology / Oceania
#    ↳ Subtopic: Epidemiology / Americas
#    ↳ Subtopic: Epidemiology / Asia
#    ↳ Subtopic: History
#    ↳ Subtopic: History / Microcephaly and other infant disorders
#    ↳ Subtopic: History / Guillain–Barré syndrome
#    ↳ Subtopic: Research
#    ↳ Subtopic: Research / Mechanism
#    ↳ Subtopic: Research / Mosquito control
# Page: Microaggression
#    ↳ Subtopic: Description
#    ↳ Subtopic: Description / Race or ethnicity
#    ↳ Subtopic: Description / Gender
#    ↳ Subtopic: Description / Sexuality and sexual orientation
#    ↳ Subtopic: Description / Intersectionality
#    ↳ Subtopic: Description / People with mental illnesses
#    ↳ Subtopic: Description / Media
#    ↳ Subtopic: Description / Ageism and intolerance
#    ↳ Subtopic: Perpetrators
#    ↳ Subtopic: Effects
#    ↳ Subtopic: Social consequences of the concept
#    ↳ Subtopic: Social consequences of the concept / Public discourse and harm to speakers
#    ↳ Subtopic: Social consequences of the concept / Public discourse and harm to speakers / College campuses
#    ↳ Subtopic: Social consequences of the concept / Distraction from more serious offenses
#    ↳ Subtopic: Social consequences of the concept / Culture of victimhood
#    ↳ Subtopic: Scientific status of the concept
# Page: Electric car
#    ↳ Subtopic: Terminology
#    ↳ Subtopic: History
#    ↳ Subtopic: Economics
#    ↳ Subtopic: Economics / Purchase cost
#    ↳ Subtopic: Economics / Purchase cost / Battery first cost
#    ↳ Subtopic: Economics / Maintenance
#    ↳ Subtopic: Economics / Electricity cost
#    ↳ Subtopic: Economics / Battery depreciation
#    ↳ Subtopic: Economics / Total cost of ownership
#    ↳ Subtopic: Economics / Dealership reluctance to sell
#    ↳ Subtopic: Environmental aspects
#    ↳ Subtopic: Performance
#    ↳ Subtopic: Performance / Acceleration and drivetrain design
#    ↳ Subtopic: Energy efficiency
#    ↳ Subtopic: Energy efficiency / Cabin heating and cooling
#    ↳ Subtopic: Safety
#    ↳ Subtopic: Safety / Risk of fire
#    ↳ Subtopic: Safety / Vehicle safety
#    ↳ Subtopic: Safety / Hazard to pedestrians
#    ↳ Subtopic: Electrical interference
#    ↳ Subtopic: Controls
#    ↳ Subtopic: Batteries
#    ↳ Subtopic: Batteries / Range
#    ↳ Subtopic: Batteries / Charging
#    ↳ Subtopic: Batteries / Charging / Home charging
#    ↳ Subtopic: Batteries / Charging / Rapid charging
#    ↳ Subtopic: Batteries / Charging / Charging time
#    ↳ Subtopic: Batteries / Charging / Battery swapping
#    ↳ Subtopic: Batteries / Charging / Range extension
#    ↳ Subtopic: Batteries / Lifespan
#    ↳ Subtopic: Batteries / Future
#    ↳ Subtopic: Electric Vehicle Charging Patents
#    ↳ Subtopic: Infrastructure
#    ↳ Subtopic: Infrastructure / Charging station
#    ↳ Subtopic: Infrastructure / Charging station / US charging standards
#    ↳ Subtopic: Infrastructure / Charging station / Connectors
#    ↳ Subtopic: Infrastructure / Vehicle-to-grid: uploading and grid buffering
#    ↳ Subtopic: Politics
#    ↳ Subtopic: Currently available electric cars
#    ↳ Subtopic: Currently available electric cars / Highway capable
#    ↳ Subtopic: Currently available electric cars / Electric cars by country
#    ↳ Subtopic: Government subsidy
# Page: Great white shark
#    ↳ Subtopic: Taxonomy
#    ↳ Subtopic: Taxonomy / Ancestry and fossil record
#    ↳ Subtopic: Distribution and habitat
#    ↳ Subtopic: Anatomy and appearance
#    ↳ Subtopic: Anatomy and appearance / Size
#    ↳ Subtopic: Anatomy and appearance / Size / Examples of large unconfirmed great whites
#    ↳ Subtopic: Anatomy and appearance / Adaptations
#    ↳ Subtopic: Anatomy and appearance / Bite force
#    ↳ Subtopic: Ecology and behavior
#    ↳ Subtopic: Ecology and behavior / Diet
#    ↳ Subtopic: Ecology and behavior / Reproduction
#    ↳ Subtopic: Ecology and behavior / Breaching behavior
#    ↳ Subtopic: Ecology and behavior / Natural threats
#    ↳ Subtopic: Conservation status
#    ↳ Subtopic: Conservation status / In Australia
#    ↳ Subtopic: Conservation status / In New Zealand
#    ↳ Subtopic: Conservation status / In North America
#    ↳ Subtopic: Relationship with humans
#    ↳ Subtopic: Relationship with humans / Shark bite incidents
#    ↳ Subtopic: Relationship with humans / Attacks on boats
#    ↳ Subtopic: Relationship with humans / In captivity
#    ↳ Subtopic: Relationship with humans / Shark tourism
# Page: Daylight saving time
#    ↳ Subtopic: Rationale
#    ↳ Subtopic: History
#    ↳ Subtopic: Procedure
#    ↳ Subtopic: Politics
#    ↳ Subtopic: Dispute over benefits and drawbacks
#    ↳ Subtopic: Dispute over benefits and drawbacks / Energy use
#    ↳ Subtopic: Dispute over benefits and drawbacks / Economic effects
#    ↳ Subtopic: Dispute over benefits and drawbacks / Public safety
#    ↳ Subtopic: Dispute over benefits and drawbacks / Health
#    ↳ Subtopic: Dispute over benefits and drawbacks / Complexity
#    ↳ Subtopic: Terminology
#    ↳ Subtopic: Computing
#    ↳ Subtopic: Computing / IANA time zone database
#    ↳ Subtopic: Computing / Microsoft Windows
#    ↳ Subtopic: Permanent daylight saving time
#    ↳ Subtopic: By country and region
# Page: Question mark
#    ↳ Subtopic: History
#    ↳ Subtopic: Scope
#    ↳ Subtopic: In other languages and scripts
#    ↳ Subtopic: In other languages and scripts / Opening and closing question marks in Spanish
#    ↳ Subtopic: In other languages and scripts / In other languages of Spain
#    ↳ Subtopic: In other languages and scripts / Armenian question mark
#    ↳ Subtopic: In other languages and scripts / Greek question mark
#    ↳ Subtopic: In other languages and scripts / Mirrored question mark in right-to-left scripts
#    ↳ Subtopic: In other languages and scripts / Fullwidth question mark in East Asian languages
#    ↳ Subtopic: In other languages and scripts / In other scripts
#    ↳ Subtopic: Stylistic variants
#    ↳ Subtopic: Rhetorical question mark
#    ↳ Subtopic: Computing
#    ↳ Subtopic: Games
#    ↳ Subtopic: Mathematics and formal logic
#    ↳ Subtopic: Medicine
# Page: Huguenots
#    ↳ Subtopic: Etymology
#    ↳ Subtopic: Demographics
#    ↳ Subtopic: History
#    ↳ Subtopic: History / Origins
#    ↳ Subtopic: History / Criticisms of the Catholic Church
#    ↳ Subtopic: History / Reform and growth
#    ↳ Subtopic: History / Wars of religion
#    ↳ Subtopic: History / Civil wars
#    ↳ Subtopic: History / St. Bartholomew's Day massacre
#    ↳ Subtopic: History / Edict of Nantes
#    ↳ Subtopic: History / Edict of Fontainebleau
#    ↳ Subtopic: History / End of persecution
#    ↳ Subtopic: History / Modern times
#    ↳ Subtopic: Exodus
#    ↳ Subtopic: Exodus / Early emigration
#    ↳ Subtopic: Exodus / South Africa
#    ↳ Subtopic: Exodus / North America
#    ↳ Subtopic: Exodus / Netherlands
#    ↳ Subtopic: Exodus / Wales
#    ↳ Subtopic: Exodus / England
#    ↳ Subtopic: Exodus / Ireland
#    ↳ Subtopic: Exodus / Germany and Scandinavia
#    ↳ Subtopic: Exodus / Effects
#    ↳ Subtopic: Symbol
#    ↳ Subtopic: Apology and honours
#    ↳ Subtopic: Apology and honours / Legacy
#    ↳ Subtopic: Apology and honours / Legacy / France
#    ↳ Subtopic: Apology and honours / Legacy / United States
#    ↳ Subtopic: Apology and honours / Legacy / England
#    ↳ Subtopic: Apology and honours / Legacy / Prussia
#    ↳ Subtopic: Apology and honours / Legacy / Ireland
#    ↳ Subtopic: Apology and honours / Legacy / South Africa
#    ↳ Subtopic: Apology and honours / Legacy / Australia
# Page: Theory of forms
#    ↳ Subtopic: Forms
#    ↳ Subtopic: Forms / Terminology
#    ↳ Subtopic: Forms / Intelligible realm and separation of the Forms
#    ↳ Subtopic: Forms / Ideal state
#    ↳ Subtopic: Evidence of Forms
#    ↳ Subtopic: Evidence of Forms / Human perception
#    ↳ Subtopic: Evidence of Forms / Perfection
#    ↳ Subtopic: Criticisms of Platonic Forms
#    ↳ Subtopic: Criticisms of Platonic Forms / Self-criticism
#    ↳ Subtopic: Criticisms of Platonic Forms / Aristotelian criticism
#    ↳ Subtopic: Dialogues that discuss Forms
# Page: Blockchain
#    ↳ Subtopic: History
#    ↳ Subtopic: Structure
#    ↳ Subtopic: Structure / Blocks
#    ↳ Subtopic: Structure / Blocks / Block time
#    ↳ Subtopic: Structure / Decentralization
#    ↳ Subtopic: Structure / Openness
#    ↳ Subtopic: Structure / Openness / Permissionless
#    ↳ Subtopic: Structure / Openness / Permissioned (private) blockchain
#    ↳ Subtopic: Structure / Openness / Disadvantages
#    ↳ Subtopic: Structure / Openness / Self-describing data
#    ↳ Subtopic: Uses
#    ↳ Subtopic: Uses / General potentials
#    ↳ Subtopic: Uses / Land registration
#    ↳ Subtopic: Uses / The Big Four
#    ↳ Subtopic: Uses / Smart contracts
#    ↳ Subtopic: Uses / Nonprofit organizations
#    ↳ Subtopic: Uses / Decentralized networks
#    ↳ Subtopic: Uses / Governments and national currencies
#    ↳ Subtopic: Uses / Banks
#    ↳ Subtopic: Uses / Other financial companies
#    ↳ Subtopic: Uses / Other uses
#    ↳ Subtopic: Academic research
#    ↳ Subtopic: Academic research / Journals
#    ↳ Subtopic: Predictions
#    ↳ Subtopic: Working
#    ↳ Subtopic: Working / Ownership integrity
#    ↳ Subtopic: Working / Transaction integrity
#    ↳ Subtopic: Working / Order integrity
# Page: Darknet market
#    ↳ Subtopic: History
#    ↳ Subtopic: History / 1970s to 2011
#    ↳ Subtopic: History / Silk Road and early markets
#    ↳ Subtopic: History / Post-Silk Road to present
#    ↳ Subtopic: Market features
#    ↳ Subtopic: Market features / Search and discussion
#    ↳ Subtopic: Market features / Customer interactions
#    ↳ Subtopic: Market features / Market types
#    ↳ Subtopic: Vendors
#    ↳ Subtopic: Products
#    ↳ Subtopic: Products / Drugs
#    ↳ Subtopic: Products / Fraud and hacking services
#    ↳ Subtopic: Products / Prohibitions and restrictions
#    ↳ Subtopic: Market operations
#    ↳ Subtopic: Fraudulent markets
#    ↳ Subtopic: Exit scams
#    ↳ Subtopic: Commentary
#    ↳ Subtopic: Size of listings
#    ↳ Subtopic: In fiction
# Page: Opioid epidemic
#    ↳ Subtopic: History in North America
#    ↳ Subtopic: History in North America / Heroin
#    ↳ Subtopic: History in North America / Oxycodone
#    ↳ Subtopic: History in North America / Fentanyl
#    ↳ Subtopic: History in North America / Pill Mills
#    ↳ Subtopic: History in North America / Trafficking
#    ↳ Subtopic: Causes
#    ↳ Subtopic: Effects
#    ↳ Subtopic: Demographics
#    ↳ Subtopic: Outside North America
#    ↳ Subtopic: Countermeasures
#    ↳ Subtopic: Countermeasures / U.S. government
#    ↳ Subtopic: Countermeasures / State and local governments
#    ↳ Subtopic: Countermeasures / Prescription drug monitoring
#    ↳ Subtopic: Countermeasures / In the media
#    ↳ Subtopic: Countermeasures / Treatment
#    ↳ Subtopic: Countermeasures / Treatment / Methadone
#    ↳ Subtopic: Countermeasures / Treatment / Naloxone
#    ↳ Subtopic: Countermeasures / Treatment / Buprenorphine
#    ↳ Subtopic: Countermeasures / Treatment / Behavioral treatment
#    ↳ Subtopic: Countermeasures / Safe injection sites
#    ↳ Subtopic: Countermeasures / Prescription drug monitoring
#    ↳ Subtopic: Countermeasures / In the media
# Page: Economics of bitcoin
#    ↳ Subtopic: Classification
#    ↳ Subtopic: General use
#    ↳ Subtopic: Buying and selling
#    ↳ Subtopic: Price and volatility
#    ↳ Subtopic: Speculative bubble dispute
#    ↳ Subtopic: Ponzi scheme concerns
#    ↳ Subtopic: Value forecasts
#    ↳ Subtopic: Obituaries
#    ↳ Subtopic: Reception
#    ↳ Subtopic: Acceptance by merchants
#    ↳ Subtopic: Acceptance by nonprofits
#    ↳ Subtopic: Healthcare providers
#    ↳ Subtopic: Payment service providers
#    ↳ Subtopic: Use in retail transactions
#    ↳ Subtopic: Financial institutions
#    ↳ Subtopic: As an investment
#    ↳ Subtopic: Venture capital
#    ↳ Subtopic: Venture capital / Crowdfunding
#    ↳ Subtopic: Political economy
# Page: Loot box
#    ↳ Subtopic: Design
#    ↳ Subtopic: History
#    ↳ Subtopic: Criticism
#    ↳ Subtopic: Criticism / Specific examples
#    ↳ Subtopic: Regulation and legislation
#    ↳ Subtopic: Regulation and legislation / Asia & Oceania
#    ↳ Subtopic: Regulation and legislation / Asia & Oceania / China
#    ↳ Subtopic: Regulation and legislation / Asia & Oceania / Japan
#    ↳ Subtopic: Regulation and legislation / Asia & Oceania / South Korea
#    ↳ Subtopic: Regulation and legislation / Asia & Oceania / Singapore
#    ↳ Subtopic: Regulation and legislation / Asia & Oceania / Australia
#    ↳ Subtopic: Regulation and legislation / Asia & Oceania / New Zealand
#    ↳ Subtopic: Regulation and legislation / Europe
#    ↳ Subtopic: Regulation and legislation / Europe / United Kingdom
#    ↳ Subtopic: Regulation and legislation / Europe / Isle of Man
#    ↳ Subtopic: Regulation and legislation / Europe / Netherlands
#    ↳ Subtopic: Regulation and legislation / Europe / Belgium
#    ↳ Subtopic: Regulation and legislation / Europe / France
#    ↳ Subtopic: Regulation and legislation / Europe / Germany
#    ↳ Subtopic: Regulation and legislation / Europe / Sweden
#    ↳ Subtopic: Regulation and legislation / North America
#    ↳ Subtopic: Regulation and legislation / North America / United States
#    ↳ Subtopic: Self-regulation
#    ↳ Subtopic: Self-regulation / Europe
#    ↳ Subtopic: Self-regulation / Japan
#    ↳ Subtopic: Self-regulation / United Kingdom
#    ↳ Subtopic: Self-regulation / United States
#    ↳ Subtopic: Self-regulation / Worldwide
#    ↳ Subtopic: Impact
# Page: Aged care in Australia
#    ↳ Subtopic: Ageing Population in Australia
#    ↳ Subtopic: Aged Care options in Australia
#    ↳ Subtopic: In-home Aged Care
#    ↳ Subtopic: In-home Aged Care / Funding for In-Home care
#    ↳ Subtopic: In-home Aged Care / Funding for In-Home care / Home Care Package
#    ↳ Subtopic: In-home Aged Care / Funding for In-Home care / Home Care Package / Commonwealth Home Support Programme
#    ↳ Subtopic: In-home Aged Care / Costs of in-home Care
#    ↳ Subtopic: 2017 Government changes to in home care
#    ↳ Subtopic: Aged care homes
#    ↳ Subtopic: Aged care homes / Funding for residential Aged Care
#    ↳ Subtopic: Aged Care Assessment
#    ↳ Subtopic: Aged Care Assessment / Home support assessment
#    ↳ Subtopic: Aged Care Assessment / Comprehensive assessment
# Page: Algorithmic bias
#    ↳ Subtopic: Definitions
#    ↳ Subtopic: Methods
#    ↳ Subtopic: History
#    ↳ Subtopic: History / Early critiques
#    ↳ Subtopic: History / Contemporary critiques
#    ↳ Subtopic: Types
#    ↳ Subtopic: Types / Pre-existing
#    ↳ Subtopic: Types / Technical
#    ↳ Subtopic: Types / Emergent
#    ↳ Subtopic: Types / Emergent / Correlations
#    ↳ Subtopic: Types / Emergent / Unanticipated uses
#    ↳ Subtopic: Types / Emergent / Feedback loops
#    ↳ Subtopic: Examples
#    ↳ Subtopic: Examples / College admissions
#    ↳ Subtopic: Examples / Plagiarism detection
#    ↳ Subtopic: Examples / Facial recognition
#    ↳ Subtopic: Examples / Social media
#    ↳ Subtopic: Impact
#    ↳ Subtopic: Impact / Commercial influences
#    ↳ Subtopic: Impact / Voting behavior
#    ↳ Subtopic: Impact / Gender discrimination
#    ↳ Subtopic: Impact / Racial discrimination
#    ↳ Subtopic: Impact / Sexual discrimination
#    ↳ Subtopic: Challenges
#    ↳ Subtopic: Challenges / Lack of transparency
#    ↳ Subtopic: Challenges / Complexity
#    ↳ Subtopic: Challenges / Lack of data about sensitive categories
#    ↳ Subtopic: Challenges / Rapid pace of change
#    ↳ Subtopic: Challenges / Rapid pace of dissemination
#    ↳ Subtopic: Challenges / Lack of consensus about goals and criteria
#    ↳ Subtopic: Regulation
#    ↳ Subtopic: Regulation / Europe
#    ↳ Subtopic: Regulation / United States
# Page: Chatbot
#    ↳ Subtopic: Background
#    ↳ Subtopic: Development
#    ↳ Subtopic: Where chatbots are found
#    ↳ Subtopic: Where chatbots are found / Messaging apps
#    ↳ Subtopic: Where chatbots are found / Messaging apps / As part of company apps and websites
#    ↳ Subtopic: Where chatbots are found / Company internal platforms
#    ↳ Subtopic: Where chatbots are found / Toys
#    ↳ Subtopic: Chatbot creation
#    ↳ Subtopic: Chatbot creation / Design
#    ↳ Subtopic: Chatbot creation / Building
#    ↳ Subtopic: Chatbot creation / Analytics
#    ↳ Subtopic: Chatbot creation / Chatbot development platforms
#    ↳ Subtopic: Malicious use
# Page: Blue-ringed octopus
#    ↳ Subtopic: Classification
#    ↳ Subtopic: Behavior
#    ↳ Subtopic: Behavior / Feeding
#    ↳ Subtopic: Reproduction
#    ↳ Subtopic: Toxicity
#    ↳ Subtopic: Toxicity / Venom
#    ↳ Subtopic: Toxicity / Effects
#    ↳ Subtopic: Toxicity / Treatment
#    ↳ Subtopic: Popular culture
# Page: Atomic force microscopy
#    ↳ Subtopic: Overview
#    ↳ Subtopic: Overview / Abilities
#    ↳ Subtopic: Overview / Other microscopy technologies
#    ↳ Subtopic: Overview / Configuration
#    ↳ Subtopic: Overview / Configuration / Detector
#    ↳ Subtopic: Overview / Configuration / Image formation
#    ↳ Subtopic: Overview / History
#    ↳ Subtopic: Overview / Applications
#    ↳ Subtopic: Principles
#    ↳ Subtopic: Principles / Imaging modes
#    ↳ Subtopic: Principles / Imaging modes / Contact mode
#    ↳ Subtopic: Principles / Imaging modes / Tapping mode
#    ↳ Subtopic: Principles / Imaging modes / Non-contact mode
#    ↳ Subtopic: Topographic image
#    ↳ Subtopic: Topographic image / What is the topographic image of atomic force microscope?
#    ↳ Subtopic: Topographic image / Topographic image of FM-AFM
#    ↳ Subtopic: Force spectroscopy
#    ↳ Subtopic: Force spectroscopy / Biological applications and other
#    ↳ Subtopic: Identification of individual surface atoms
#    ↳ Subtopic: Probe
#    ↳ Subtopic: AFM cantilever-deflection measurement
#    ↳ Subtopic: AFM cantilever-deflection measurement / Beam-deflection measurement
#    ↳ Subtopic: AFM cantilever-deflection measurement / Other deflection-measurement methods
#    ↳ Subtopic: Piezoelectric scanners
#    ↳ Subtopic: Advantages and disadvantages
#    ↳ Subtopic: Advantages and disadvantages / Advantages
#    ↳ Subtopic: Advantages and disadvantages / Disadvantages
#    ↳ Subtopic: Other applications in various fields of study
# Page: Herbalism
#    ↳ Subtopic: Synonyms
#    ↳ Subtopic: History
#    ↳ Subtopic: Modern herbal medicine
#    ↳ Subtopic: Modern herbal medicine / Clinical tests
#    ↳ Subtopic: Modern herbal medicine / Prevalence of use
#    ↳ Subtopic: Modern herbal medicine / Herbal preparations
#    ↳ Subtopic: Modern herbal medicine / Safety
#    ↳ Subtopic: Modern herbal medicine / Labeling accuracy
#    ↳ Subtopic: Modern herbal medicine / Practitioners of herbalism
#    ↳ Subtopic: Modern herbal medicine / Government regulations
#    ↳ Subtopic: Modern herbal medicine / Scientific criticism
#    ↳ Subtopic: Phytotherapy
#    ↳ Subtopic: Traditional systems
#    ↳ Subtopic: Traditional systems / Africa
#    ↳ Subtopic: Traditional systems / Americas
#    ↳ Subtopic: Traditional systems / China
#    ↳ Subtopic: Traditional systems / India
#    ↳ Subtopic: Traditional systems / Indonesia
#    ↳ Subtopic: Herbal philosophy and spiritual practices
#    ↳ Subtopic: Uses of herbal medicines by animals
# Page: Workhouse
#    ↳ Subtopic: Legal and social background
#    ↳ Subtopic: Legal and social background / Medieval to Early Modern period
#    ↳ Subtopic: Legal and social background / Georgian era
#    ↳ Subtopic: Legal and social background / 1834 act
#    ↳ Subtopic: Early Victorian workhouses
#    ↳ Subtopic: Early Victorian workhouses / Admission and discharge
#    ↳ Subtopic: Early Victorian workhouses / Work
#    ↳ Subtopic: Early Victorian workhouses / Diet
#    ↳ Subtopic: Early Victorian workhouses / Education
#    ↳ Subtopic: Early Victorian workhouses / Religion
#    ↳ Subtopic: Early Victorian workhouses / Discipline
#    ↳ Subtopic: Early Victorian workhouses / Management and staffing
#    ↳ Subtopic: Later developments and abolition
#    ↳ Subtopic: Modern view
#    ↳ Subtopic: In art and literature
# Page: Eggnog
#    ↳ Subtopic: Terminology
#    ↳ Subtopic: History
#    ↳ Subtopic: History / Etymology and origins
#    ↳ Subtopic: History / Development
#    ↳ Subtopic: Ingredients and serving style
#    ↳ Subtopic: Ingredients and serving style / Homemade
#    ↳ Subtopic: Ingredients and serving style / Commercially prepared
#    ↳ Subtopic: Ingredients and serving style / Commercially prepared / Non-dairy and vegan versions
#    ↳ Subtopic: Ingredients and serving style / Serving and presentation
#    ↳ Subtopic: Use as flavouring
#    ↳ Subtopic: Health and safety
#    ↳ Subtopic: Health and safety / Raw eggs
#    ↳ Subtopic: Health and safety / Alcohol content
#    ↳ Subtopic: Health and safety / Nutritional aspects
#    ↳ Subtopic: Reception and consumption
#    ↳ Subtopic: In fiction
#    ↳ Subtopic: Cited books
# Page: Healthcare in Canada
#    ↳ Subtopic: Current status
#    ↳ Subtopic: Current status / Benefits and features
#    ↳ Subtopic: Current status / Statistics
#    ↳ Subtopic: Public opinion
#    ↳ Subtopic: Economics
#    ↳ Subtopic: History
#    ↳ Subtopic: Government involvement
#    ↳ Subtopic: Private sector
#    ↳ Subtopic: Physicians and medical organization
#    ↳ Subtopic: Criticisms
#    ↳ Subtopic: Criticisms / Wait times
#    ↳ Subtopic: Criticisms / Wait times / Counter-criticism: Some longer wait times can benefit patients
#    ↳ Subtopic: Criticisms / Restrictions on privately funded healthcare
#    ↳ Subtopic: Criticisms / Cross-border health care
#    ↳ Subtopic: Criticisms / Cross-border health care / Canadians visiting the US to receive healthcare
#    ↳ Subtopic: Criticisms / Cross-border health care / Americans visiting Canada to receive healthcare
#    ↳ Subtopic: Criticisms / Limited coverage
#    ↳ Subtopic: Criticisms / Portability and provincial residency requirements
#    ↳ Subtopic: Comparison to other countries
# Page: Salmon run
#    ↳ Subtopic: Background
#    ↳ Subtopic: Return from the ocean
#    ↳ Subtopic: Obstacles to the run
#    ↳ Subtopic: The spawning
#    ↳ Subtopic: Keystone species
#    ↳ Subtopic: Prospects
#    ↳ Subtopic: Notable runs
#    ↳ Subtopic: Cited sources
# Page: Xerostomia
#    ↳ Subtopic: Definition
#    ↳ Subtopic: Signs and symptoms
#    ↳ Subtopic: Differential diagnosis
#    ↳ Subtopic: Differential diagnosis / Physiologic
#    ↳ Subtopic: Differential diagnosis / Drug induced
#    ↳ Subtopic: Differential diagnosis / Sjögren's syndrome
#    ↳ Subtopic: Differential diagnosis / Sicca syndrome
#    ↳ Subtopic: Differential diagnosis / Other causes
#    ↳ Subtopic: Diagnostic approach
#    ↳ Subtopic: Treatment
#    ↳ Subtopic: Epidemiology
#    ↳ Subtopic: History
# Page: Entomophagy
#    ↳ Subtopic: Definition
#    ↳ Subtopic: In non-humans
#    ↳ Subtopic: History
#    ↳ Subtopic: Uses
#    ↳ Subtopic: Uses / Traditional cultures
#    ↳ Subtopic: Uses / Western culture
#    ↳ Subtopic: Uses / Crickets
#    ↳ Subtopic: Uses / Bee brood
#    ↳ Subtopic: Uses / Restaurants
#    ↳ Subtopic: Uses / Pet food
#    ↳ Subtopic: Advantages
#    ↳ Subtopic: Advantages / Food security
#    ↳ Subtopic: Advantages / Food security / Minilivestock
#    ↳ Subtopic: Advantages / Food security / Therapeutic foods
#    ↳ Subtopic: Advantages / Food security / Indigenous cultivation
#    ↳ Subtopic: Advantages / Food security / Pest harvesting
#    ↳ Subtopic: Advantages / Environmental benefits
#    ↳ Subtopic: Advantages / Economic benefits
#    ↳ Subtopic: Advantages / Nutritional benefits
#    ↳ Subtopic: Advantages / Impacts of animal agriculture
#    ↳ Subtopic: Advantages / Impacts of animal agriculture / Greenhouse gas emission
#    ↳ Subtopic: Advantages / Impacts of animal agriculture / Land use
#    ↳ Subtopic: Advantages / Impacts of animal agriculture / Water pollution
#    ↳ Subtopic: Disadvantages
#    ↳ Subtopic: Disadvantages / Spoilage
#    ↳ Subtopic: Disadvantages / Toxicity
#    ↳ Subtopic: Cultural taboo
#    ↳ Subtopic: Policy instruments
# Page: Aerobic fermentation
#    ↳ Subtopic: Origin of Crabtree effect in yeast
#    ↳ Subtopic: Origin of Crabtree effect in yeast / Driving forces
#    ↳ Subtopic: Genomic basis of the crabtree effect
#    ↳ Subtopic: Genomic basis of the crabtree effect / Expansion of hexose transporter genes
#    ↳ Subtopic: Genomic basis of the crabtree effect / CNV in glycolysis genes
#    ↳ Subtopic: Genomic basis of the crabtree effect / CNV in fermentation genes
#    ↳ Subtopic: Genomic basis of the crabtree effect / Differential expression
#    ↳ Subtopic: Domestication and aerobic fermentation
#    ↳ Subtopic: Aerobic fermentation in non-yeast species
#    ↳ Subtopic: Aerobic fermentation in non-yeast species / Plants
#    ↳ Subtopic: Aerobic fermentation in non-yeast species / Trypanosomatids
#    ↳ Subtopic: Aerobic fermentation in non-yeast species / E. coli mutant
#    ↳ Subtopic: Aerobic fermentation in non-yeast species / Tumor cells

# %%
import trec_car.read_data as trec_car
import csv

input_path = "benchmarkY2.cbor-outlines.cbor"
output_path = "trec_car_queries.tsv"

with open(input_path, 'rb') as f, open(output_path, 'w', encoding='utf-8', newline='') as out_file:
    writer = csv.writer(out_file, delimiter='\t')
    writer.writerow(['page_title', 'query_id', 'query_text'])

    query_id_counter = 0

    for page in trec_car.iter_outlines(f):
        page_title = page.page_name

        for section_path in page.flat_headings_list():
            heading_text = " / ".join([h.heading for h in section_path])
            query_text = f"{page_title} / {heading_text}"
            query_id = f"query_{query_id_counter}"
            query_id_counter += 1

            writer.writerow([page_title, query_id, query_text])
